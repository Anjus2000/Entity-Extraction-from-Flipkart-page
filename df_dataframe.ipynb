# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

products=[]
prices=[]
ratings=[]
results=[]


urls=['https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
     'https://www.flipkart.com/search?q=laptops&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_2_0_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_2_0_na_na_na&as-pos=2&as-type=HISTORY&suggestionId=laptops&requestId=3df6e11f-d4d4-41be-a3f4-bd5fe4faacd7',
     ]

for url in urls:
    def scrape_flipkart_product_info(url):
        response = requests.get(url)
        html_content = response.content
        soup = BeautifulSoup(html_content, "html.parser")

        for a in soup.findAll('a', href=True, attrs={'class': '_1fQZEK'}):

            name = a.find("div", {"class": "_4rR01T"})
            rating = a.find("div", {"class": "_3LWZlK"})
            price = a.find("div", {"class": "_30jeq3 _1_WHN1"})
            
            try:
                products.append(name.text)
            except:
                products.append("No product name available")

            try:
                prices.append(price.text)
            except:
                prices.append("No price available")

            try:
                ratings.append(rating.text)
            except:
                ratings.append("No rating available")

        return (
            products,
            ratings,
            prices,
        )


    products, ratings, prices = scrape_flipkart_product_info(url)
    results.append({
        "Product Name": products,
        "Rating": ratings,
        "Price": prices})

    # Getting pandas dataframe
df = pd.DataFrame({'Product': products, 'Price': prices, 'Ratings': ratings})
df.head()


df.shape
# Out:
# (48, 3)

# %%
df
# Out:
#                                               Product    Price  \
# 0   Yuwa Y32-S 80 cm (32 inch) HD Ready LED Smart ...   ₹8,399
# 1   Yuwa Bezel Less/Frameless 80 cm (32 inch) HD R...   ₹8,699
# 2   SAMSUNG 80 cm (32 Inch) HD Ready LED Smart Tiz...  ₹13,499
# 3   OnePlus Y1 80 cm (32 inch) HD Ready LED Smart ...  ₹11,999
# 4   OnePlus Y1 100 cm (40 inch) Full HD LED Smart ...  ₹18,999
# 5   Thomson Alpha 80 cm (32 inch) HD Ready LED Sma...   ₹8,499
# 6   Mi 5A 80 cm (32 inch) HD Ready LED Smart Andro...  ₹13,999
# 7   Dyanora 109 cm (43 inch) Full HD LED Smart And...  ₹15,999
# 8   Infinix Y1 80 cm (32 inch) HD Ready LED Smart ...   ₹8,999
# 9   OnePlus Y1S 108 cm (43 inch) Full HD LED Smart...  ₹23,999
# 10     LG 80 cm (32 inch) HD Ready LED Smart WebOS TV  ₹13,990
# 11  Dyanora 108 cm (43 inch) Full HD LED Smart And...  ₹15,499
# 12  OnePlus Y1S 80 cm (32 inch) HD Ready LED Smart...  ₹13,999
# 13  acer I Series 80 cm (32 inch) HD Ready LED Sma...  ₹11,499
# 14  iFFALCON by TCL F53 79.97 cm (32 inch) HD Read...   ₹9,499
# 15  XElectron Android 11 80 cm (32 inch) HD Ready ...   ₹8,949
# 16  realme 80 cm (32 inch) HD Ready LED Smart Andr...  ₹13,999
# 17  iFFALCON by TCL F53 100 cm (40 inch) Full HD L...  ₹14,999
# 18  acer I Series 109 cm (43 inch) Ultra HD (4K) L...  ₹23,999
# 19  Vu 108 cm (43 inch) Ultra HD (4K) LED Smart We...  ₹19,999
# 20  BeethoSOL 80 cm (32 inch) HD Ready LED Smart A...   ₹7,499
# 21  realme NEO 80 cm (32 inch) HD Ready LED Smart ...  ₹11,999
# 22  realme 100.3 cm (40 inch) Full HD LED Smart An...  ₹19,999
# 23  Vu 138 cm (55 inch) Ultra HD (4K) LED Smart We...  ₹29,999
# 24  ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...  ₹33,990
# 25  HP 14s Intel Core i3 11th Gen - (8 GB/256 GB S...  ₹35,490
# 26  Lenovo V15 G2 Core i3 11th Gen - (8 GB/512 GB ...  ₹33,999
# 27  HP Pavilion Ryzen 5 Hexa Core AMD R5-5600H - (...  ₹54,990
# 28  acer Aspire 3 Ryzen 3 Dual Core 3250U - (8 GB/...  ₹26,990
# 29  ASUS VivoBook 14 (2021) Celeron Dual Core - (4...  ₹23,990
# 30  Lenovo Intel Celeron Dual Core - (8 GB/256 GB ...  ₹27,000
# 31  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...  ₹49,990
# 32  HP Ryzen 3 Dual Core 3250U - (8 GB/256 GB SSD/...  ₹29,990
# 33  DELL Vostro Core i3 11th Gen - (8 GB/1 TB HDD/...  ₹37,990
# 34  HP Athlon Dual Core 3050U - (8 GB/512 GB SSD/W...  ₹29,490
# 35  ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 ...  ₹35,990
# 36  RedmiBook Pro Core i5 11th Gen - (8 GB/512 GB ...  ₹39,990
# 37  DELL Vostro Ryzen 7 Octa Core 5825U - (16 GB/5...  ₹99,693
# 38  HP 15s Intel Core i3 11th Gen - (8 GB/512 GB S...  ₹40,950
# 39  ASUS TUF Gaming A17 with 90Whr Battery Ryzen 5...  ₹52,990
# 40  MSI Bravo 15 Ryzen 5 Hexa Core AMD R5-5600H - ...  ₹49,990
# 41  HP G8 Ryzen 3 Dual Core AMD Ryzen 3 3250U - (8...  ₹28,490
# 42  HP Ryzen 5 Hexa Core 5500U - (16 GB/512 GB SSD...  ₹49,123
# 43  HP 15s Intel Core i5 12th Gen - (8 GB/512 GB S...  ₹58,990
# 44  DELL Vostro Pentium Gold - (8 GB/256 GB SSD/Wi...  ₹54,392
# 45  ASUS Vivobook 15 Core i3 10th Gen - (8 GB/512 ...  ₹33,990
# 46  DELL Core i5 12th Gen - (16 GB/512 GB SSD/Wind...  ₹65,990
# 47  HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/...  ₹45,123
#
#                 Ratings
# 0   No rating available
# 1   No rating available
# 2                   4.4
# 3                   4.3
# 4                   4.3
# 5                   4.5
# 6                   4.4
# 7                   4.1
# 8                   4.2
# 9                   4.3
# 10                  4.4
# 11                  4.1
# 12                  4.3
# 13                  4.4
# 14                  4.3
# 15                  3.8
# 16                  4.3
# 17                  4.3
# 18                  4.4
# 19                  4.4
# 20                  4.1
# 21                  4.3
# 22                  4.3
# 23                  4.4
# 24                  4.3
# 25                  4.2
# 26                    4
# 27                  4.4
# 28                  4.2
# 29                  4.1
# 30                  4.1
# 31                  4.4
# 32                  4.1
# 33                  4.1
# 34                    4
# 35                  4.2
# 36                  4.1
# 37  No rating available
# 38                  4.2
# 39                  4.4
# 40                  4.4
# 41  No rating available
# 42                  4.3
# 43                  4.2
# 44                  4.7
# 45                  4.2
# 46                  4.7
# 47                  4.3
